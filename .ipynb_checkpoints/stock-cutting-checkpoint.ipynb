# %%
import pulp as pl
import math
import time

# %%
def solve_cutting_stock(
    L,                       # stock length
    item_lengths,            # list  l_i
    demands,                 # list  d_i
    cost_bar=1.0,            # c_bar
    cost_waste=1e-4,         # c_w
    bigM=None,               # upper bound on bars
    solver=None              
):
    n_items = len(item_lengths)
    assert n_items == len(demands)

    if bigM is None:
        # lower bound = total required length / stock length
        LB = math.ceil(sum(d * l for l, d in zip(demands, item_lengths)) / L)
        # add a small safety buffer (e.g. 5 %)
        bigM = math.ceil(1.05 * LB)

    bars = range(bigM)
    items = range(n_items)

    prob = pl.LpProblem("CuttingStock_BarIndexed", pl.LpMinimize)

    u = pl.LpVariable.dicts("useBar", bars, lowBound=0, upBound=1, cat="Binary")
    y = pl.LpVariable.dicts(
        "cut", [(i, j) for i in items for j in bars],
        lowBound=0, cat="Integer"
    )
    s = pl.LpVariable.dicts("trim", bars, lowBound=0, cat="Continuous")

    # OBJECTIVE
    prob += pl.lpSum(cost_bar * u[j] + cost_waste * s[j] for j in bars), "TotalCost"

    # DEMAND
    for i in items:
        prob += pl.lpSum(y[i, j] for j in bars) >= demands[i], f"demand_{i}"

    # Capacity (exact) on each bar: Σ ℓ_i * y_ij + s_j = L * u_j
    for j in bars:
        prob += (
            pl.lpSum(item_lengths[i] * y[i, j] for i in items) + s[j]
            == L * u[j],
            f"capacity_{j}",
        )
    for j in range(bigM-1):                                      
        prob += (L * u[j] - s[j]) >= (L * u[j+1] - s[j+1]), f"sym_{j}"

    if solver is None:
        solver = pl.PULP_CBC_CMD(msg=True, presolve='on', timeLimit=120)
    prob.solve(solver)

    # REPORT
    print(f"Status: {pl.LpStatus[prob.status]}")
    print(f"Objective value = {pl.value(prob.objective):.4f}")
    used_bars = [j for j in bars if pl.value(u[j]) > 0.5]
    print(f"Bars used = {len(used_bars)} of {bigM}")
    print()

    for j in used_bars:
        trim = pl.value(s[j])
        cuts = [(i, int(pl.value(y[i, j]))) for i in items if pl.value(y[i, j]) > 0.5]
        pattern_str = ", ".join(f"{qty}×{item_lengths[i]}" for i, qty in cuts)
        print(f"Bar {j:>2}: {pattern_str:<25}  trim = {trim:.2f}")

    return prob

# %%
# %%time

stock_length = 6000                      # mm
lengths     = [1820, 2350, 410]          # mm
demands     = [50,   35,   120]          # required counts of each

solve_cutting_stock(
    L=stock_length,
    item_lengths=lengths,
    demands=demands,
    cost_bar=1.0,
    cost_waste=1e-4 #PENALIZATION
)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/f8/0hzmswyj0sn232kss0n40r_80000gn/T/5af3de573dca4db385f2cb936497b11a-pulp.mps -sec 120 -presolve on -timeMode elapsed -branch -printingOptions all -solution /var/folders/f8/0hzmswyj0sn232kss0n40r_80000gn/T/5af3de573dca4db385f2cb936497b11a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 48 COLUMNS
# At line 769 RHS
# At line 813 BOUNDS
# At line 974 ENDATA
# Problem MODEL has 43 rows, 200 columns and 320 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 120
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 37.075 - 0.00 seconds
# Cgl0003I 0 fixed, 40 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 43 rows, 200 columns (160 integer (40 of which binary)) and 320 elements
# Cutoff increment increased from 1e-05 to 9.99e-05
# Cbc0031I 113 added rows had average density of 24.477876
# Cbc0013I At root node, 113 cuts changed objective from 37.075 to 38.006039 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 227 row cuts average 5.4 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 7512 row cuts average 22.8 elements, 0 column cuts (0 active)  in 0.033 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 2069 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.066 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.029 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 2185 row cuts average 6.3 elements, 0 column cuts (0 active)  in 0.023 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 38.006039 (0.46 seconds)
# Cbc0012I Integer solution of 38.432 found by rounding after 23207 iterations and 145 nodes (1.09 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of 38.391 found by RINS after 23207 iterations and 145 nodes (1.09 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 7 rows 14 columns
# Cbc0016I Integer solution of 38.373 found by strong branching after 24249 iterations and 291 nodes (1.18 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 29 rows 100 columns
# Cbc0038I Full problem 43 rows 200 columns, reduced to 29 rows 99 columns
# Cbc0016I Integer solution of 38.197 found by strong branching after 39014 iterations and 500 nodes (2.02 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 19 rows 60 columns
# Cbc0038I Full problem 43 rows 200 columns, reduced to 38 rows 137 columns
# Cbc0038I Full problem 43 rows 200 columns, reduced to 36 rows 130 columns
# Cbc0038I Full problem 43 rows 200 columns, reduced to 37 rows 131 columns
# Cbc0038I Full problem 43 rows 200 columns, reduced to 37 rows 132 columns
# Cbc0038I Full problem 43 rows 200 columns, reduced to 36 rows 131 columns
# Cbc0010I After 1000 nodes, 409 on tree, 38.197 best solution, best possible 38.006039 (5.98 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 38 rows 136 columns
# Cbc0010I After 2000 nodes, 444 on tree, 38.197 best solution, best possible 38.006039 (6.61 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 36 rows 128 columns
# Cbc0010I After 3000 nodes, 441 on tree, 38.197 best solution, best possible 38.006039 (7.13 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 38 rows 134 columns
# Cbc0010I After 4000 nodes, 443 on tree, 38.197 best solution, best possible 38.006039 (7.68 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 36 rows 128 columns
# Cbc0010I After 5000 nodes, 443 on tree, 38.197 best solution, best possible 38.006039 (8.17 seconds)
# Cbc0010I After 6000 nodes, 494 on tree, 38.197 best solution, best possible 38.006039 (8.64 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 32 rows 113 columns
# Cbc0010I After 7000 nodes, 488 on tree, 38.197 best solution, best possible 38.006039 (9.07 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 30 rows 104 columns
# Cbc0010I After 8000 nodes, 490 on tree, 38.197 best solution, best possible 38.006039 (9.47 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 35 rows 120 columns
# Cbc0010I After 9000 nodes, 486 on tree, 38.197 best solution, best possible 38.006039 (9.90 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 36 rows 126 columns
# Cbc0010I After 10000 nodes, 525 on tree, 38.197 best solution, best possible 38.006039 (10.41 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 36 rows 129 columns
# Cbc0010I After 11000 nodes, 529 on tree, 38.197 best solution, best possible 38.006039 (10.87 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 42 rows 149 columns
# Cbc0010I After 12000 nodes, 1020 on tree, 38.197 best solution, best possible 38.007605 (14.47 seconds)
# Cbc0010I After 13000 nodes, 1519 on tree, 38.197 best solution, best possible 38.007915 (18.18 seconds)
# Cbc0010I After 14000 nodes, 1567 on tree, 38.197 best solution, best possible 38.007915 (18.64 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 43 rows 159 columns
# Cbc0010I After 15000 nodes, 2052 on tree, 38.197 best solution, best possible 38.008112 (21.67 seconds)
# Cbc0010I After 16000 nodes, 2538 on tree, 38.197 best solution, best possible 38.008276 (25.07 seconds)
# Cbc0010I After 17000 nodes, 3024 on tree, 38.197 best solution, best possible 38.008657 (28.53 seconds)
# Cbc0010I After 18000 nodes, 3091 on tree, 38.197 best solution, best possible 38.008657 (29.04 seconds)
# Cbc0010I After 19000 nodes, 3585 on tree, 38.197 best solution, best possible 38.008993 (32.20 seconds)
# Cbc0010I After 20000 nodes, 4083 on tree, 38.197 best solution, best possible 38.009359 (35.13 seconds)
# Cbc0010I After 21000 nodes, 4578 on tree, 38.197 best solution, best possible 38.009592 (38.50 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 42 rows 151 columns
# Cbc0010I After 22000 nodes, 4632 on tree, 38.197 best solution, best possible 38.009592 (39.21 seconds)
# Cbc0010I After 23000 nodes, 5129 on tree, 38.197 best solution, best possible 38.009825 (41.84 seconds)
# Cbc0010I After 24000 nodes, 5624 on tree, 38.197 best solution, best possible 38.010053 (44.53 seconds)
# Cbc0010I After 25000 nodes, 6119 on tree, 38.197 best solution, best possible 38.010249 (47.54 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 37 rows 132 columns
# Cbc0004I Integer solution of 38.191 found after 1563095 iterations and 25383 nodes (47.81 seconds)
# Cbc0010I After 26000 nodes, 6484 on tree, 38.191 best solution, best possible 38.010249 (49.40 seconds)
# Cbc0010I After 27000 nodes, 6981 on tree, 38.191 best solution, best possible 38.010458 (52.21 seconds)
# Cbc0010I After 28000 nodes, 7477 on tree, 38.191 best solution, best possible 38.010694 (54.97 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 43 rows 159 columns
# Cbc0010I After 29000 nodes, 7977 on tree, 38.191 best solution, best possible 38.010878 (57.63 seconds)
# Cbc0010I After 30000 nodes, 8037 on tree, 38.191 best solution, best possible 38.010878 (58.07 seconds)
# Cbc0010I After 31000 nodes, 8535 on tree, 38.191 best solution, best possible 38.011057 (60.67 seconds)
# Cbc0010I After 32000 nodes, 9031 on tree, 38.191 best solution, best possible 38.011202 (63.21 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 42 rows 156 columns
# Cbc0010I After 33000 nodes, 9525 on tree, 38.191 best solution, best possible 38.011354 (65.59 seconds)
# Cbc0010I After 34000 nodes, 9579 on tree, 38.191 best solution, best possible 38.011354 (66.07 seconds)
# Cbc0010I After 35000 nodes, 10075 on tree, 38.191 best solution, best possible 38.0115 (68.63 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 35 rows 123 columns
# Cbc0010I After 36000 nodes, 10566 on tree, 38.191 best solution, best possible 38.0115 (70.31 seconds)
# Cbc0010I After 37000 nodes, 10559 on tree, 38.191 best solution, best possible 38.0115 (70.69 seconds)
# Cbc0010I After 38000 nodes, 10609 on tree, 38.191 best solution, best possible 38.0115 (71.20 seconds)
# Cbc0010I After 39000 nodes, 11104 on tree, 38.191 best solution, best possible 38.0115 (72.78 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 34 rows 118 columns
# Cbc0010I After 40000 nodes, 11599 on tree, 38.191 best solution, best possible 38.0115 (74.42 seconds)
# Cbc0010I After 41000 nodes, 11592 on tree, 38.191 best solution, best possible 38.0115 (74.81 seconds)
# Cbc0010I After 42000 nodes, 11647 on tree, 38.191 best solution, best possible 38.0115 (75.24 seconds)
# Cbc0010I After 43000 nodes, 12138 on tree, 38.191 best solution, best possible 38.0115 (76.90 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 36 rows 126 columns
# Cbc0010I After 44000 nodes, 12628 on tree, 38.191 best solution, best possible 38.0115 (78.48 seconds)
# Cbc0010I After 45000 nodes, 12624 on tree, 38.191 best solution, best possible 38.0115 (78.88 seconds)
# Cbc0010I After 46000 nodes, 12680 on tree, 38.191 best solution, best possible 38.0115 (79.29 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 34 rows 119 columns
# Cbc0010I After 47000 nodes, 13174 on tree, 38.191 best solution, best possible 38.0115 (80.87 seconds)
# Cbc0010I After 48000 nodes, 13667 on tree, 38.191 best solution, best possible 38.0115 (82.57 seconds)
# Cbc0010I After 49000 nodes, 13695 on tree, 38.191 best solution, best possible 38.0115 (82.89 seconds)
# Cbc0010I After 50000 nodes, 13751 on tree, 38.191 best solution, best possible 38.0115 (83.23 seconds)
# Cbc0038I Full problem 43 rows 200 columns, reduced to 35 rows 122 columns
# Cbc0010I After 51000 nodes, 14247 on tree, 38.191 best solution, best possible 38.0115 (85.08 seconds)
# Cbc0010I After 52000 nodes, 14743 on tree, 38.191 best solution, best possible 38.0115 (86.81 seconds)
# Cbc0012I Integer solution of 38.186 found by rounding after 2975091 iterations and 52965 nodes (87.05 seconds)
# Cbc0010I After 53000 nodes, 14744 on tree, 38.186 best solution, best possible 38.0115 (87.10 seconds)
# Cbc0010I After 54000 nodes, 14790 on tree, 38.186 best solution, best possible 38.011501 (87.55 seconds)
# Cbc0010I After 55000 nodes, 15290 on tree, 38.186 best solution, best possible 38.011501 (89.35 seconds)
# Cbc0010I After 56000 nodes, 15787 on tree, 38.186 best solution, best possible 38.011501 (91.00 seconds)
# Cbc0004I Integer solution of 38.168 found after 3118552 iterations and 56693 nodes (91.14 seconds)
# Cbc0010I After 57000 nodes, 15830 on tree, 38.168 best solution, best possible 38.011501 (91.69 seconds)
# Cbc0010I After 58000 nodes, 15864 on tree, 38.168 best solution, best possible 38.011501 (92.41 seconds)
# Cbc0010I After 59000 nodes, 16359 on tree, 38.168 best solution, best possible 38.011501 (94.23 seconds)
# Cbc0010I After 60000 nodes, 16853 on tree, 38.168 best solution, best possible 38.011501 (95.91 seconds)
# Cbc0010I After 61000 nodes, 16841 on tree, 38.168 best solution, best possible 38.011501 (96.15 seconds)
# Cbc0010I After 62000 nodes, 16885 on tree, 38.168 best solution, best possible 38.011501 (96.75 seconds)
# Cbc0010I After 63000 nodes, 17383 on tree, 38.168 best solution, best possible 38.011501 (98.62 seconds)
# Cbc0010I After 64000 nodes, 17873 on tree, 38.168 best solution, best possible 38.011501 (100.21 seconds)
# Cbc0010I After 65000 nodes, 17881 on tree, 38.168 best solution, best possible 38.011501 (100.50 seconds)
# Cbc0010I After 66000 nodes, 17913 on tree, 38.168 best solution, best possible 38.011501 (101.11 seconds)
# Cbc0010I After 67000 nodes, 18410 on tree, 38.168 best solution, best possible 38.011501 (102.82 seconds)
# Cbc0010I After 68000 nodes, 18906 on tree, 38.168 best solution, best possible 38.011501 (104.34 seconds)
# Cbc0010I After 69000 nodes, 18900 on tree, 38.168 best solution, best possible 38.011501 (104.59 seconds)
# Cbc0010I After 70000 nodes, 18932 on tree, 38.168 best solution, best possible 38.011501 (105.14 seconds)
# Cbc0010I After 71000 nodes, 19427 on tree, 38.168 best solution, best possible 38.011501 (107.02 seconds)
# Cbc0010I After 72000 nodes, 19921 on tree, 38.168 best solution, best possible 38.011501 (109.02 seconds)
# Cbc0010I After 73000 nodes, 19918 on tree, 38.168 best solution, best possible 38.011501 (109.30 seconds)
# Cbc0010I After 74000 nodes, 19966 on tree, 38.168 best solution, best possible 38.011501 (109.78 seconds)
# Cbc0010I After 75000 nodes, 20461 on tree, 38.168 best solution, best possible 38.011501 (111.67 seconds)
# Cbc0010I After 76000 nodes, 20958 on tree, 38.168 best solution, best possible 38.011501 (113.48 seconds)
# Cbc0010I After 77000 nodes, 20964 on tree, 38.168 best solution, best possible 38.011501 (113.74 seconds)
# Cbc0010I After 78000 nodes, 21008 on tree, 38.168 best solution, best possible 38.011501 (114.26 seconds)
# Cbc0010I After 79000 nodes, 21501 on tree, 38.168 best solution, best possible 38.011501 (116.06 seconds)
# Cbc0010I After 80000 nodes, 22000 on tree, 38.168 best solution, best possible 38.011501 (117.89 seconds)
# Cbc0010I After 81000 nodes, 21991 on tree, 38.168 best solution, best possible 38.011501 (118.17 seconds)
# Cbc0010I After 82000 nodes, 22018 on tree, 38.168 best solution, best possible 38.011501 (118.71 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 38.168 (best possible 38.011501), took 4348180 iterations and 194703 nodes (120.24 seconds)
# Cbc0032I Strong branching done 57044 times (157224 iterations), fathomed 714 nodes and fixed 1920 variables
# Cbc0041I Maximum depth 109, 48305 variables fixed on reduced cost (complete fathoming 7 times, 112000 nodes taking 204337 iterations)
# Cuts at root node changed objective from 37.075 to 38.006
# Probing was tried 100 times and created 227 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# Gomory was tried 78941 times and created 1786380 cuts of which 0 were active after adding rounds of cuts (12.453 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 78988 times and created 675091 cuts of which 0 were active after adding rounds of cuts (9.560 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.029 seconds)
# TwoMirCuts was tried 78941 times and created 869923 cuts of which 0 were active after adding rounds of cuts (9.991 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                38.16800000
# Lower bound:                    38.012
# Gap:                            0.00
# Enumerated nodes:               194703
# Total iterations:               4348180
# Time (CPU seconds):             118.59
# Time (Wallclock seconds):       120.24
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       118.59   (Wallclock seconds):       120.24
#
# Status: Optimal
# Objective value = 38.1680
# Bars used = 38 of 40
#
# Bar  0: 2×1820, 1×2350             trim = 10.00
# Bar  1: 1×1820, 10×410             trim = 80.00
# Bar  2: 2×1820, 1×2350             trim = 10.00
# Bar  3: 2×2350, 3×410              trim = 70.00
# Bar  4: 2×1820, 1×2350             trim = 10.00
# Bar  6: 2×1820, 1×2350             trim = 10.00
# Bar  7: 2×2350, 3×410              trim = 70.00
# Bar  8: 1×1820, 10×410             trim = 80.00
# Bar  9: 2×2350, 3×410              trim = 70.00
# Bar 10: 2×1820, 1×2350             trim = 10.00
# Bar 11: 2×1820, 1×2350             trim = 10.00
# Bar 12: 1×1820, 10×410             trim = 80.00
# Bar 13: 1×1820, 10×410             trim = 80.00
# Bar 14: 2×1820, 1×2350             trim = 10.00
# Bar 15: 2×1820, 1×2350             trim = 10.00
# Bar 17: 1×1820, 10×410             trim = 80.00
# Bar 18: 3×1820, 1×410              trim = 130.00
# Bar 19: 1×1820, 10×410             trim = 80.00
# Bar 20: 2×1820, 1×2350             trim = 10.00
# Bar 21: 1×1820, 10×410             trim = 80.00
# Bar 22: 1×1820, 10×410             trim = 80.00
# Bar 23: 1×1820, 10×410             trim = 80.00
# Bar 24: 2×1820, 1×2350             trim = 10.00
# Bar 25: 2×2350, 3×410              trim = 70.00
# Bar 26: 2×1820, 1×2350             trim = 10.00
# Bar 27: 2×1820, 1×2350             trim = 10.00
# Bar 28: 2×2350, 3×410              trim = 70.00
# Bar 29: 2×2350, 3×410              trim = 70.00
# Bar 30: 2×1820, 1×2350             trim = 10.00
# Bar 31: 2×1820, 1×2350             trim = 10.00
# Bar 32: 2×2350, 3×410              trim = 70.00
# Bar 33: 2×1820, 1×2350             trim = 10.00
# Bar 34: 1×1820, 10×410             trim = 80.00
# Bar 35: 2×2350, 3×410              trim = 70.00
# Bar 36: 2×1820, 1×2350             trim = 10.00
# Bar 37: 2×1820, 1×2350             trim = 10.00
# Bar 38: 2×1820, 1×2350             trim = 10.00
# Bar 39: 2×1820, 1×2350             trim = 10.00
# CPU times: user 5.9 ms, sys: 6.09 ms, total: 12 ms
# Wall time: 2min
# CuttingStock_BarIndexed:
# MINIMIZE
# 0.0001*trim_0 + 0.0001*trim_1 + 0.0001*trim_10 + 0.0001*trim_11 + 0.0001*trim_12 + 0.0001*trim_13 + 0.0001*trim_14 + 0.0001*trim_15 + 0.0001*trim_16 + 0.0001*trim_17 + 0.0001*trim_18 + 0.0001*trim_19 + 0.0001*trim_2 + 0.0001*trim_20 + 0.0001*trim_21 + 0.0001*trim_22 + 0.0001*trim_23 + 0.0001*trim_24 + 0.0001*trim_25 + 0.0001*trim_26 + 0.0001*trim_27 + 0.0001*trim_28 + 0.0001*trim_29 + 0.0001*trim_3 + 0.0001*trim_30 + 0.0001*trim_31 + 0.0001*trim_32 + 0.0001*trim_33 + 0.0001*trim_34 + 0.0001*trim_35 + 0.0001*trim_36 + 0.0001*trim_37 + 0.0001*trim_38 + 0.0001*trim_39 + 0.0001*trim_4 + 0.0001*trim_5 + 0.0001*trim_6 + 0.0001*trim_7 + 0.0001*trim_8 + 0.0001*trim_9 + 1.0*useBar_0 + 1.0*useBar_1 + 1.0*useBar_10 + 1.0*useBar_11 + 1.0*useBar_12 + 1.0*useBar_13 + 1.0*useBar_14 + 1.0*useBar_15 + 1.0*useBar_16 + 1.0*useBar_17 + 1.0*useBar_18 + 1.0*useBar_19 + 1.0*useBar_2 + 1.0*useBar_20 + 1.0*useBar_21 + 1.0*useBar_22 + 1.0*useBar_23 + 1.0*useBar_24 + 1.0*useBar_25 + 1.0*useBar_26 + 1.0*useBar_27 + 1.0*useBar_28 + 1.0*useBar_29 + 1.0*useBar_3 + 1.0*useBar_30 + 1.0*useBar_31 + 1.0*useBar_32 + 1.0*useBar_33 + 1.0*useBar_34 + 1.0*useBar_35 + 1.0*useBar_36 + 1.0*useBar_37 + 1.0*useBar_38 + 1.0*useBar_39 + 1.0*useBar_4 + 1.0*useBar_5 + 1.0*useBar_6 + 1.0*useBar_7 + 1.0*useBar_8 + 1.0*useBar_9 + 0.0
# SUBJECT TO
# demand_0: cut_(0,_0) + cut_(0,_1) + cut_(0,_10) + cut_(0,_11) + cut_(0,_12)
#  + cut_(0,_13) + cut_(0,_14) + cut_(0,_15) + cut_(0,_16) + cut_(0,_17)
#  + cut_(0,_18) + cut_(0,_19) + cut_(0,_2) + cut_(0,_20) + cut_(0,_21)
#  + cut_(0,_22) + cut_(0,_23) + cut_(0,_24) + cut_(0,_25) + cut_(0,_26)
#  + cut_(0,_27) + cut_(0,_28) + cut_(0,_29) + cut_(0,_3) + cut_(0,_30)
#  + cut_(0,_31) + cut_(0,_32) + cut_(0,_33) + cut_(0,_34) + cut_(0,_35)
#  + cut_(0,_36) + cut_(0,_37) + cut_(0,_38) + cut_(0,_39) + cut_(0,_4)
#  + cut_(0,_5) + cut_(0,_6) + cut_(0,_7) + cut_(0,_8) + cut_(0,_9) >= 50
#
# demand_1: cut_(1,_0) + cut_(1,_1) + cut_(1,_10) + cut_(1,_11) + cut_(1,_12)
#  + cut_(1,_13) + cut_(1,_14) + cut_(1,_15) + cut_(1,_16) + cut_(1,_17)
#  + cut_(1,_18) + cut_(1,_19) + cut_(1,_2) + cut_(1,_20) + cut_(1,_21)
#  + cut_(1,_22) + cut_(1,_23) + cut_(1,_24) + cut_(1,_25) + cut_(1,_26)
#  + cut_(1,_27) + cut_(1,_28) + cut_(1,_29) + cut_(1,_3) + cut_(1,_30)
#  + cut_(1,_31) + cut_(1,_32) + cut_(1,_33) + cut_(1,_34) + cut_(1,_35)
#  + cut_(1,_36) + cut_(1,_37) + cut_(1,_38) + cut_(1,_39) + cut_(1,_4)
#  + cut_(1,_5) + cut_(1,_6) + cut_(1,_7) + cut_(1,_8) + cut_(1,_9) >= 35
#
# demand_2: cut_(2,_0) + cut_(2,_1) + cut_(2,_10) + cut_(2,_11) + cut_(2,_12)
#  + cut_(2,_13) + cut_(2,_14) + cut_(2,_15) + cut_(2,_16) + cut_(2,_17)
#  + cut_(2,_18) + cut_(2,_19) + cut_(2,_2) + cut_(2,_20) + cut_(2,_21)
#  + cut_(2,_22) + cut_(2,_23) + cut_(2,_24) + cut_(2,_25) + cut_(2,_26)
#  + cut_(2,_27) + cut_(2,_28) + cut_(2,_29) + cut_(2,_3) + cut_(2,_30)
#  + cut_(2,_31) + cut_(2,_32) + cut_(2,_33) + cut_(2,_34) + cut_(2,_35)
#  + cut_(2,_36) + cut_(2,_37) + cut_(2,_38) + cut_(2,_39) + cut_(2,_4)
#  + cut_(2,_5) + cut_(2,_6) + cut_(2,_7) + cut_(2,_8) + cut_(2,_9) >= 120
#
# capacity_0: 1820 cut_(0,_0) + 2350 cut_(1,_0) + 410 cut_(2,_0) + trim_0
#  - 6000 useBar_0 = 0
#
# capacity_1: 1820 cut_(0,_1) + 2350 cut_(1,_1) + 410 cut_(2,_1) + trim_1
#  - 6000 useBar_1 = 0
#
# capacity_2: 1820 cut_(0,_2) + 2350 cut_(1,_2) + 410 cut_(2,_2) + trim_2
#  - 6000 useBar_2 = 0
#
# capacity_3: 1820 cut_(0,_3) + 2350 cut_(1,_3) + 410 cut_(2,_3) + trim_3
#  - 6000 useBar_3 = 0
#
# capacity_4: 1820 cut_(0,_4) + 2350 cut_(1,_4) + 410 cut_(2,_4) + trim_4
#  - 6000 useBar_4 = 0
#
# capacity_5: 1820 cut_(0,_5) + 2350 cut_(1,_5) + 410 cut_(2,_5) + trim_5
#  - 6000 useBar_5 = 0
#
# capacity_6: 1820 cut_(0,_6) + 2350 cut_(1,_6) + 410 cut_(2,_6) + trim_6
#  - 6000 useBar_6 = 0
#
# capacity_7: 1820 cut_(0,_7) + 2350 cut_(1,_7) + 410 cut_(2,_7) + trim_7
#  - 6000 useBar_7 = 0
#
# capacity_8: 1820 cut_(0,_8) + 2350 cut_(1,_8) + 410 cut_(2,_8) + trim_8
#  - 6000 useBar_8 = 0
#
# capacity_9: 1820 cut_(0,_9) + 2350 cut_(1,_9) + 410 cut_(2,_9) + trim_9
#  - 6000 useBar_9 = 0
#
# capacity_10: 1820 cut_(0,_10) + 2350 cut_(1,_10) + 410 cut_(2,_10) + trim_10
#  - 6000 useBar_10 = 0
#
# capacity_11: 1820 cut_(0,_11) + 2350 cut_(1,_11) + 410 cut_(2,_11) + trim_11
#  - 6000 useBar_11 = 0
#
# capacity_12: 1820 cut_(0,_12) + 2350 cut_(1,_12) + 410 cut_(2,_12) + trim_12
#  - 6000 useBar_12 = 0
#
# capacity_13: 1820 cut_(0,_13) + 2350 cut_(1,_13) + 410 cut_(2,_13) + trim_13
#  - 6000 useBar_13 = 0
#
# capacity_14: 1820 cut_(0,_14) + 2350 cut_(1,_14) + 410 cut_(2,_14) + trim_14
#  - 6000 useBar_14 = 0
#
# capacity_15: 1820 cut_(0,_15) + 2350 cut_(1,_15) + 410 cut_(2,_15) + trim_15
#  - 6000 useBar_15 = 0
#
# capacity_16: 1820 cut_(0,_16) + 2350 cut_(1,_16) + 410 cut_(2,_16) + trim_16
#  - 6000 useBar_16 = 0
#
# capacity_17: 1820 cut_(0,_17) + 2350 cut_(1,_17) + 410 cut_(2,_17) + trim_17
#  - 6000 useBar_17 = 0
#
# capacity_18: 1820 cut_(0,_18) + 2350 cut_(1,_18) + 410 cut_(2,_18) + trim_18
#  - 6000 useBar_18 = 0
#
# capacity_19: 1820 cut_(0,_19) + 2350 cut_(1,_19) + 410 cut_(2,_19) + trim_19
#  - 6000 useBar_19 = 0
#
# capacity_20: 1820 cut_(0,_20) + 2350 cut_(1,_20) + 410 cut_(2,_20) + trim_20
#  - 6000 useBar_20 = 0
#
# capacity_21: 1820 cut_(0,_21) + 2350 cut_(1,_21) + 410 cut_(2,_21) + trim_21
#  - 6000 useBar_21 = 0
#
# capacity_22: 1820 cut_(0,_22) + 2350 cut_(1,_22) + 410 cut_(2,_22) + trim_22
#  - 6000 useBar_22 = 0
#
# capacity_23: 1820 cut_(0,_23) + 2350 cut_(1,_23) + 410 cut_(2,_23) + trim_23
#  - 6000 useBar_23 = 0
#
# capacity_24: 1820 cut_(0,_24) + 2350 cut_(1,_24) + 410 cut_(2,_24) + trim_24
#  - 6000 useBar_24 = 0
#
# capacity_25: 1820 cut_(0,_25) + 2350 cut_(1,_25) + 410 cut_(2,_25) + trim_25
#  - 6000 useBar_25 = 0
#
# capacity_26: 1820 cut_(0,_26) + 2350 cut_(1,_26) + 410 cut_(2,_26) + trim_26
#  - 6000 useBar_26 = 0
#
# capacity_27: 1820 cut_(0,_27) + 2350 cut_(1,_27) + 410 cut_(2,_27) + trim_27
#  - 6000 useBar_27 = 0
#
# capacity_28: 1820 cut_(0,_28) + 2350 cut_(1,_28) + 410 cut_(2,_28) + trim_28
#  - 6000 useBar_28 = 0
#
# capacity_29: 1820 cut_(0,_29) + 2350 cut_(1,_29) + 410 cut_(2,_29) + trim_29
#  - 6000 useBar_29 = 0
#
# capacity_30: 1820 cut_(0,_30) + 2350 cut_(1,_30) + 410 cut_(2,_30) + trim_30
#  - 6000 useBar_30 = 0
#
# capacity_31: 1820 cut_(0,_31) + 2350 cut_(1,_31) + 410 cut_(2,_31) + trim_31
#  - 6000 useBar_31 = 0
#
# capacity_32: 1820 cut_(0,_32) + 2350 cut_(1,_32) + 410 cut_(2,_32) + trim_32
#  - 6000 useBar_32 = 0
#
# capacity_33: 1820 cut_(0,_33) + 2350 cut_(1,_33) + 410 cut_(2,_33) + trim_33
#  - 6000 useBar_33 = 0
#
# capacity_34: 1820 cut_(0,_34) + 2350 cut_(1,_34) + 410 cut_(2,_34) + trim_34
#  - 6000 useBar_34 = 0
#
# capacity_35: 1820 cut_(0,_35) + 2350 cut_(1,_35) + 410 cut_(2,_35) + trim_35
#  - 6000 useBar_35 = 0
#
# capacity_36: 1820 cut_(0,_36) + 2350 cut_(1,_36) + 410 cut_(2,_36) + trim_36
#  - 6000 useBar_36 = 0
#
# capacity_37: 1820 cut_(0,_37) + 2350 cut_(1,_37) + 410 cut_(2,_37) + trim_37
#  - 6000 useBar_37 = 0
#
# capacity_38: 1820 cut_(0,_38) + 2350 cut_(1,_38) + 410 cut_(2,_38) + trim_38
#  - 6000 useBar_38 = 0
#
# capacity_39: 1820 cut_(0,_39) + 2350 cut_(1,_39) + 410 cut_(2,_39) + trim_39
#  - 6000 useBar_39 = 0
#
# VARIABLES
# 0 <= cut_(0,_0) Integer
# 0 <= cut_(0,_1) Integer
# 0 <= cut_(0,_10) Integer
# 0 <= cut_(0,_11) Integer
# 0 <= cut_(0,_12) Integer
# 0 <= cut_(0,_13) Integer
# 0 <= cut_(0,_14) Integer
# 0 <= cut_(0,_15) Integer
# 0 <= cut_(0,_16) Integer
# 0 <= cut_(0,_17) Integer
# 0 <= cut_(0,_18) Integer
# 0 <= cut_(0,_19) Integer
# 0 <= cut_(0,_2) Integer
# 0 <= cut_(0,_20) Integer
# 0 <= cut_(0,_21) Integer
# 0 <= cut_(0,_22) Integer
# 0 <= cut_(0,_23) Integer
# 0 <= cut_(0,_24) Integer
# 0 <= cut_(0,_25) Integer
# 0 <= cut_(0,_26) Integer
# 0 <= cut_(0,_27) Integer
# 0 <= cut_(0,_28) Integer
# 0 <= cut_(0,_29) Integer
# 0 <= cut_(0,_3) Integer
# 0 <= cut_(0,_30) Integer
# 0 <= cut_(0,_31) Integer
# 0 <= cut_(0,_32) Integer
# 0 <= cut_(0,_33) Integer
# 0 <= cut_(0,_34) Integer
# 0 <= cut_(0,_35) Integer
# 0 <= cut_(0,_36) Integer
# 0 <= cut_(0,_37) Integer
# 0 <= cut_(0,_38) Integer
# 0 <= cut_(0,_39) Integer
# 0 <= cut_(0,_4) Integer
# 0 <= cut_(0,_5) Integer
# 0 <= cut_(0,_6) Integer
# 0 <= cut_(0,_7) Integer
# 0 <= cut_(0,_8) Integer
# 0 <= cut_(0,_9) Integer
# 0 <= cut_(1,_0) Integer
# 0 <= cut_(1,_1) Integer
# 0 <= cut_(1,_10) Integer
# 0 <= cut_(1,_11) Integer
# 0 <= cut_(1,_12) Integer
# 0 <= cut_(1,_13) Integer
# 0 <= cut_(1,_14) Integer
# 0 <= cut_(1,_15) Integer
# 0 <= cut_(1,_16) Integer
# 0 <= cut_(1,_17) Integer
# 0 <= cut_(1,_18) Integer
# 0 <= cut_(1,_19) Integer
# 0 <= cut_(1,_2) Integer
# 0 <= cut_(1,_20) Integer
# 0 <= cut_(1,_21) Integer
# 0 <= cut_(1,_22) Integer
# 0 <= cut_(1,_23) Integer
# 0 <= cut_(1,_24) Integer
# 0 <= cut_(1,_25) Integer
# 0 <= cut_(1,_26) Integer
# 0 <= cut_(1,_27) Integer
# 0 <= cut_(1,_28) Integer
# 0 <= cut_(1,_29) Integer
# 0 <= cut_(1,_3) Integer
# 0 <= cut_(1,_30) Integer
# 0 <= cut_(1,_31) Integer
# 0 <= cut_(1,_32) Integer
# 0 <= cut_(1,_33) Integer
# 0 <= cut_(1,_34) Integer
# 0 <= cut_(1,_35) Integer
# 0 <= cut_(1,_36) Integer
# 0 <= cut_(1,_37) Integer
# 0 <= cut_(1,_38) Integer
# 0 <= cut_(1,_39) Integer
# 0 <= cut_(1,_4) Integer
# 0 <= cut_(1,_5) Integer
# 0 <= cut_(1,_6) Integer
# 0 <= cut_(1,_7) Integer
# 0 <= cut_(1,_8) Integer
# 0 <= cut_(1,_9) Integer
# 0 <= cut_(2,_0) Integer
# 0 <= cut_(2,_1) Integer
# 0 <= cut_(2,_10) Integer
# 0 <= cut_(2,_11) Integer
# 0 <= cut_(2,_12) Integer
# 0 <= cut_(2,_13) Integer
# 0 <= cut_(2,_14) Integer
# 0 <= cut_(2,_15) Integer
# 0 <= cut_(2,_16) Integer
# 0 <= cut_(2,_17) Integer
# 0 <= cut_(2,_18) Integer
# 0 <= cut_(2,_19) Integer
# 0 <= cut_(2,_2) Integer
# 0 <= cut_(2,_20) Integer
# 0 <= cut_(2,_21) Integer
# 0 <= cut_(2,_22) Integer
# 0 <= cut_(2,_23) Integer
# 0 <= cut_(2,_24) Integer
# 0 <= cut_(2,_25) Integer
# 0 <= cut_(2,_26) Integer
# 0 <= cut_(2,_27) Integer
# 0 <= cut_(2,_28) Integer
# 0 <= cut_(2,_29) Integer
# 0 <= cut_(2,_3) Integer
# 0 <= cut_(2,_30) Integer
# 0 <= cut_(2,_31) Integer
# 0 <= cut_(2,_32) Integer
# 0 <= cut_(2,_33) Integer
# 0 <= cut_(2,_34) Integer
# 0 <= cut_(2,_35) Integer
# 0 <= cut_(2,_36) Integer
# 0 <= cut_(2,_37) Integer
# 0 <= cut_(2,_38) Integer
# 0 <= cut_(2,_39) Integer
# 0 <= cut_(2,_4) Integer
# 0 <= cut_(2,_5) Integer
# 0 <= cut_(2,_6) Integer
# 0 <= cut_(2,_7) Integer
# 0 <= cut_(2,_8) Integer
# 0 <= cut_(2,_9) Integer
# trim_0 Continuous
# trim_1 Continuous
# trim_10 Continuous
# trim_11 Continuous
# trim_12 Continuous
# trim_13 Continuous
# trim_14 Continuous
# trim_15 Continuous
# trim_16 Continuous
# trim_17 Continuous
# trim_18 Continuous
# trim_19 Continuous
# trim_2 Continuous
# trim_20 Continuous
# trim_21 Continuous
# trim_22 Continuous
# trim_23 Continuous
# trim_24 Continuous
# trim_25 Continuous
# trim_26 Continuous
# trim_27 Continuous
# trim_28 Continuous
# trim_29 Continuous
# trim_3 Continuous
# trim_30 Continuous
# trim_31 Continuous
# trim_32 Continuous
# trim_33 Continuous
# trim_34 Continuous
# trim_35 Continuous
# trim_36 Continuous
# trim_37 Continuous
# trim_38 Continuous
# trim_39 Continuous
# trim_4 Continuous
# trim_5 Continuous
# trim_6 Continuous
# trim_7 Continuous
# trim_8 Continuous
# trim_9 Continuous
# 0 <= useBar_0 <= 1 Integer
# 0 <= useBar_1 <= 1 Integer
# 0 <= useBar_10 <= 1 Integer
# 0 <= useBar_11 <= 1 Integer
# 0 <= useBar_12 <= 1 Integer
# 0 <= useBar_13 <= 1 Integer
# 0 <= useBar_14 <= 1 Integer
# 0 <= useBar_15 <= 1 Integer
# 0 <= useBar_16 <= 1 Integer
# 0 <= useBar_17 <= 1 Integer
# 0 <= useBar_18 <= 1 Integer
# 0 <= useBar_19 <= 1 Integer
# 0 <= useBar_2 <= 1 Integer
# 0 <= useBar_20 <= 1 Integer
# 0 <= useBar_21 <= 1 Integer
# 0 <= useBar_22 <= 1 Integer
# 0 <= useBar_23 <= 1 Integer
# 0 <= useBar_24 <= 1 Integer
# 0 <= useBar_25 <= 1 Integer
# 0 <= useBar_26 <= 1 Integer
# 0 <= useBar_27 <= 1 Integer
# 0 <= useBar_28 <= 1 Integer
# 0 <= useBar_29 <= 1 Integer
# 0 <= useBar_3 <= 1 Integer
# 0 <= useBar_30 <= 1 Integer
# 0 <= useBar_31 <= 1 Integer
# 0 <= useBar_32 <= 1 Integer
# 0 <= useBar_33 <= 1 Integer
# 0 <= useBar_34 <= 1 Integer
# 0 <= useBar_35 <= 1 Integer
# 0 <= useBar_36 <= 1 Integer
# 0 <= useBar_37 <= 1 Integer
# 0 <= useBar_38 <= 1 Integer
# 0 <= useBar_39 <= 1 Integer
# 0 <= useBar_4 <= 1 Integer
# 0 <= useBar_5 <= 1 Integer
# 0 <= useBar_6 <= 1 Integer
# 0 <= useBar_7 <= 1 Integer
# 0 <= useBar_8 <= 1 Integer
# 0 <= useBar_9 <= 1 Integer
