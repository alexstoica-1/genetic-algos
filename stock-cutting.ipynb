# %% [markdown]
# # ILP solving the 1D cutting stock problem

# %% [markdown]
# Here I am minimizing the number of bars used and the waste loss, per each bar.

# %%
import pulp as pl
import math
import time

# %%
def solve_cutting_stock(
    L,                       # stock length
    item_lengths,            # list  l_i
    demands,                 # list  d_i
    cost_bar=1.0,            # c_bar
    cost_waste=1e-4,         # c_w - usually small 
    bigM=None,              
    solver=None,
    report_filename=None
):
    n_items = len(item_lengths)
    assert n_items == len(demands)

    if bigM is None:
        # LB = total required length / stock length
        LB = math.ceil(sum(d * l for l, d in zip(demands, item_lengths)) / L)
        # small safety buffer, e.g. 5 %
        bigM = math.ceil(1.05 * LB)

    bars = range(bigM)
    items = range(n_items)

    prob = pl.LpProblem("CuttingStock_BarIndexed", pl.LpMinimize)

    u = pl.LpVariable.dicts("useBar", bars, lowBound=0, upBound=1, cat="Binary")
    y = pl.LpVariable.dicts(
        "cut", [(i, j) for i in items for j in bars],
        lowBound=0, cat="Integer"
    )
    s = pl.LpVariable.dicts("trim", bars, lowBound=0, cat="Continuous")

    # OBJECTIVE
    prob += pl.lpSum(cost_bar * u[j] + cost_waste * s[j] for j in bars), "TotalCost"

    # DEMAND
    for i in items:
        prob += pl.lpSum(y[i, j] for j in bars) >= demands[i], f"demand_{i}"

    # Capacity on each bar: Σ l_i * y_ij + s_j = L * u_j
    for j in bars:
        prob += (
            pl.lpSum(item_lengths[i] * y[i, j] for i in items) + s[j]
            == L * u[j],
            f"capacity_{j}",
        )
    for j in range(bigM-1):                                      
        prob += (L * u[j] - s[j]) >= (L * u[j+1] - s[j+1]), f"sym_{j}"

    if solver is None:
        solver = pl.PULP_CBC_CMD(msg=False, presolve='on', timeLimit=300)
    prob.solve(solver)
    #print(f"Status: {pl.LpStatus[prob.status]}")
    #print(f"Objective value = {pl.value(prob.objective):.2f}")

    # REPORT
    output_lines = [] # start with a list and append everything
    output_lines.append(f"Status: {pl.LpStatus[prob.status]}")
    output_lines.append(f"Objective value = {pl.value(prob.objective):.2f}")
    used_bars = [j for j in bars if pl.value(u[j]) > 0.5]
    output_lines.append(f"Bars used = {len(used_bars)} of {bigM}\n")

    for j in used_bars:
        trim = pl.value(s[j])
        cuts = [(i, int(pl.value(y[i, j]))) for i in items if pl.value(y[i, j]) > 0.5]
        pattern_str = ", ".join(f"{qty}×{item_lengths[i]}" for i, qty in cuts)
        output_lines.append(f"Bar {j:>2}: {pattern_str:<25}  trim = {trim:.2f}")

    report = "\n".join(output_lines) # join the list together in the report
    print(report)

    if report_filename is not None:
        with open(report_filename, "w") as f:
            f.write(report)

    return prob

# %%
# %%time

stock_length = 6000                      # mm
lengths     = [1820, 2350, 410]          # mm
demands     = [50,   35,   40]          # required counts of each

solve_cutting_stock(
    L=stock_length,
    item_lengths=lengths,
    demands=demands,
    cost_bar=1.0,
    cost_waste=1e-4, 
    report_filename="stock_report.txt"
)
# Out:
# Status: Optimal
# Objective value = 32.11
# Bars used = 32 of 34
#
# Bar  0: 2×1820, 1×2350             trim = 10.00
# Bar  1: 2×1820, 1×2350             trim = 10.00
# Bar  2: 2×1820, 1×2350             trim = 10.00
# Bar  3: 2×1820, 1×2350             trim = 10.00
# Bar  4: 2×1820, 1×2350             trim = 10.00
# Bar  5: 2×1820, 1×2350             trim = 10.00
# Bar  6: 2×1820, 1×2350             trim = 10.00
# Bar  7: 2×1820, 1×2350             trim = 10.00
# Bar  8: 2×1820, 1×2350             trim = 10.00
# Bar  9: 2×1820, 1×2350             trim = 10.00
# Bar 10: 2×1820, 1×2350             trim = 10.00
# Bar 11: 2×1820, 1×2350             trim = 10.00
# Bar 12: 2×1820, 1×2350             trim = 10.00
# Bar 13: 2×1820, 1×2350             trim = 10.00
# Bar 14: 2×1820, 1×2350             trim = 10.00
# Bar 15: 2×1820, 1×2350             trim = 10.00
# Bar 16: 2×1820, 1×2350             trim = 10.00
# Bar 17: 2×1820, 1×2350             trim = 10.00
# Bar 18: 2×1820, 1×2350             trim = 10.00
# Bar 19: 2×1820, 1×2350             trim = 10.00
# Bar 20: 2×1820, 1×2350             trim = 10.00
# Bar 21: 2×1820, 1×2350             trim = 10.00
# Bar 22: 2×1820, 1×2350             trim = 10.00
# Bar 23: 2×1820, 1×2350             trim = 10.00
# Bar 24: 2×2350, 3×410              trim = 70.00
# Bar 25: 2×2350, 3×410              trim = 70.00
# Bar 26: 2×2350, 3×410              trim = 70.00
# Bar 27: 2×2350, 3×410              trim = 70.00
# Bar 28: 2×2350, 3×410              trim = 70.00
# Bar 29: 1×1820, 10×410             trim = 80.00
# Bar 30: 1×1820, 10×410             trim = 80.00
# Bar 31: 1×2350, 8×410              trim = 370.00
# CPU times: user 18.8 ms, sys: 12.2 ms, total: 31 ms
# Wall time: 1min 47s
# CuttingStock_BarIndexed:
# MINIMIZE
# 0.0001*trim_0 + 0.0001*trim_1 + 0.0001*trim_10 + 0.0001*trim_11 + 0.0001*trim_12 + 0.0001*trim_13 + 0.0001*trim_14 + 0.0001*trim_15 + 0.0001*trim_16 + 0.0001*trim_17 + 0.0001*trim_18 + 0.0001*trim_19 + 0.0001*trim_2 + 0.0001*trim_20 + 0.0001*trim_21 + 0.0001*trim_22 + 0.0001*trim_23 + 0.0001*trim_24 + 0.0001*trim_25 + 0.0001*trim_26 + 0.0001*trim_27 + 0.0001*trim_28 + 0.0001*trim_29 + 0.0001*trim_3 + 0.0001*trim_30 + 0.0001*trim_31 + 0.0001*trim_32 + 0.0001*trim_33 + 0.0001*trim_4 + 0.0001*trim_5 + 0.0001*trim_6 + 0.0001*trim_7 + 0.0001*trim_8 + 0.0001*trim_9 + 1.0*useBar_0 + 1.0*useBar_1 + 1.0*useBar_10 + 1.0*useBar_11 + 1.0*useBar_12 + 1.0*useBar_13 + 1.0*useBar_14 + 1.0*useBar_15 + 1.0*useBar_16 + 1.0*useBar_17 + 1.0*useBar_18 + 1.0*useBar_19 + 1.0*useBar_2 + 1.0*useBar_20 + 1.0*useBar_21 + 1.0*useBar_22 + 1.0*useBar_23 + 1.0*useBar_24 + 1.0*useBar_25 + 1.0*useBar_26 + 1.0*useBar_27 + 1.0*useBar_28 + 1.0*useBar_29 + 1.0*useBar_3 + 1.0*useBar_30 + 1.0*useBar_31 + 1.0*useBar_32 + 1.0*useBar_33 + 1.0*useBar_4 + 1.0*useBar_5 + 1.0*useBar_6 + 1.0*useBar_7 + 1.0*useBar_8 + 1.0*useBar_9 + 0.0
# SUBJECT TO
# demand_0: cut_(0,_0) + cut_(0,_1) + cut_(0,_10) + cut_(0,_11) + cut_(0,_12)
#  + cut_(0,_13) + cut_(0,_14) + cut_(0,_15) + cut_(0,_16) + cut_(0,_17)
#  + cut_(0,_18) + cut_(0,_19) + cut_(0,_2) + cut_(0,_20) + cut_(0,_21)
#  + cut_(0,_22) + cut_(0,_23) + cut_(0,_24) + cut_(0,_25) + cut_(0,_26)
#  + cut_(0,_27) + cut_(0,_28) + cut_(0,_29) + cut_(0,_3) + cut_(0,_30)
#  + cut_(0,_31) + cut_(0,_32) + cut_(0,_33) + cut_(0,_4) + cut_(0,_5)
#  + cut_(0,_6) + cut_(0,_7) + cut_(0,_8) + cut_(0,_9) >= 50
#
# demand_1: cut_(1,_0) + cut_(1,_1) + cut_(1,_10) + cut_(1,_11) + cut_(1,_12)
#  + cut_(1,_13) + cut_(1,_14) + cut_(1,_15) + cut_(1,_16) + cut_(1,_17)
#  + cut_(1,_18) + cut_(1,_19) + cut_(1,_2) + cut_(1,_20) + cut_(1,_21)
#  + cut_(1,_22) + cut_(1,_23) + cut_(1,_24) + cut_(1,_25) + cut_(1,_26)
#  + cut_(1,_27) + cut_(1,_28) + cut_(1,_29) + cut_(1,_3) + cut_(1,_30)
#  + cut_(1,_31) + cut_(1,_32) + cut_(1,_33) + cut_(1,_4) + cut_(1,_5)
#  + cut_(1,_6) + cut_(1,_7) + cut_(1,_8) + cut_(1,_9) >= 35
#
# demand_2: cut_(2,_0) + cut_(2,_1) + cut_(2,_10) + cut_(2,_11) + cut_(2,_12)
#  + cut_(2,_13) + cut_(2,_14) + cut_(2,_15) + cut_(2,_16) + cut_(2,_17)
#  + cut_(2,_18) + cut_(2,_19) + cut_(2,_2) + cut_(2,_20) + cut_(2,_21)
#  + cut_(2,_22) + cut_(2,_23) + cut_(2,_24) + cut_(2,_25) + cut_(2,_26)
#  + cut_(2,_27) + cut_(2,_28) + cut_(2,_29) + cut_(2,_3) + cut_(2,_30)
#  + cut_(2,_31) + cut_(2,_32) + cut_(2,_33) + cut_(2,_4) + cut_(2,_5)
#  + cut_(2,_6) + cut_(2,_7) + cut_(2,_8) + cut_(2,_9) >= 40
#
# capacity_0: 1820 cut_(0,_0) + 2350 cut_(1,_0) + 410 cut_(2,_0) + trim_0
#  - 6000 useBar_0 = 0
#
# capacity_1: 1820 cut_(0,_1) + 2350 cut_(1,_1) + 410 cut_(2,_1) + trim_1
#  - 6000 useBar_1 = 0
#
# capacity_2: 1820 cut_(0,_2) + 2350 cut_(1,_2) + 410 cut_(2,_2) + trim_2
#  - 6000 useBar_2 = 0
#
# capacity_3: 1820 cut_(0,_3) + 2350 cut_(1,_3) + 410 cut_(2,_3) + trim_3
#  - 6000 useBar_3 = 0
#
# capacity_4: 1820 cut_(0,_4) + 2350 cut_(1,_4) + 410 cut_(2,_4) + trim_4
#  - 6000 useBar_4 = 0
#
# capacity_5: 1820 cut_(0,_5) + 2350 cut_(1,_5) + 410 cut_(2,_5) + trim_5
#  - 6000 useBar_5 = 0
#
# capacity_6: 1820 cut_(0,_6) + 2350 cut_(1,_6) + 410 cut_(2,_6) + trim_6
#  - 6000 useBar_6 = 0
#
# capacity_7: 1820 cut_(0,_7) + 2350 cut_(1,_7) + 410 cut_(2,_7) + trim_7
#  - 6000 useBar_7 = 0
#
# capacity_8: 1820 cut_(0,_8) + 2350 cut_(1,_8) + 410 cut_(2,_8) + trim_8
#  - 6000 useBar_8 = 0
#
# capacity_9: 1820 cut_(0,_9) + 2350 cut_(1,_9) + 410 cut_(2,_9) + trim_9
#  - 6000 useBar_9 = 0
#
# capacity_10: 1820 cut_(0,_10) + 2350 cut_(1,_10) + 410 cut_(2,_10) + trim_10
#  - 6000 useBar_10 = 0
#
# capacity_11: 1820 cut_(0,_11) + 2350 cut_(1,_11) + 410 cut_(2,_11) + trim_11
#  - 6000 useBar_11 = 0
#
# capacity_12: 1820 cut_(0,_12) + 2350 cut_(1,_12) + 410 cut_(2,_12) + trim_12
#  - 6000 useBar_12 = 0
#
# capacity_13: 1820 cut_(0,_13) + 2350 cut_(1,_13) + 410 cut_(2,_13) + trim_13
#  - 6000 useBar_13 = 0
#
# capacity_14: 1820 cut_(0,_14) + 2350 cut_(1,_14) + 410 cut_(2,_14) + trim_14
#  - 6000 useBar_14 = 0
#
# capacity_15: 1820 cut_(0,_15) + 2350 cut_(1,_15) + 410 cut_(2,_15) + trim_15
#  - 6000 useBar_15 = 0
#
# capacity_16: 1820 cut_(0,_16) + 2350 cut_(1,_16) + 410 cut_(2,_16) + trim_16
#  - 6000 useBar_16 = 0
#
# capacity_17: 1820 cut_(0,_17) + 2350 cut_(1,_17) + 410 cut_(2,_17) + trim_17
#  - 6000 useBar_17 = 0
#
# capacity_18: 1820 cut_(0,_18) + 2350 cut_(1,_18) + 410 cut_(2,_18) + trim_18
#  - 6000 useBar_18 = 0
#
# capacity_19: 1820 cut_(0,_19) + 2350 cut_(1,_19) + 410 cut_(2,_19) + trim_19
#  - 6000 useBar_19 = 0
#
# capacity_20: 1820 cut_(0,_20) + 2350 cut_(1,_20) + 410 cut_(2,_20) + trim_20
#  - 6000 useBar_20 = 0
#
# capacity_21: 1820 cut_(0,_21) + 2350 cut_(1,_21) + 410 cut_(2,_21) + trim_21
#  - 6000 useBar_21 = 0
#
# capacity_22: 1820 cut_(0,_22) + 2350 cut_(1,_22) + 410 cut_(2,_22) + trim_22
#  - 6000 useBar_22 = 0
#
# capacity_23: 1820 cut_(0,_23) + 2350 cut_(1,_23) + 410 cut_(2,_23) + trim_23
#  - 6000 useBar_23 = 0
#
# capacity_24: 1820 cut_(0,_24) + 2350 cut_(1,_24) + 410 cut_(2,_24) + trim_24
#  - 6000 useBar_24 = 0
#
# capacity_25: 1820 cut_(0,_25) + 2350 cut_(1,_25) + 410 cut_(2,_25) + trim_25
#  - 6000 useBar_25 = 0
#
# capacity_26: 1820 cut_(0,_26) + 2350 cut_(1,_26) + 410 cut_(2,_26) + trim_26
#  - 6000 useBar_26 = 0
#
# capacity_27: 1820 cut_(0,_27) + 2350 cut_(1,_27) + 410 cut_(2,_27) + trim_27
#  - 6000 useBar_27 = 0
#
# capacity_28: 1820 cut_(0,_28) + 2350 cut_(1,_28) + 410 cut_(2,_28) + trim_28
#  - 6000 useBar_28 = 0
#
# capacity_29: 1820 cut_(0,_29) + 2350 cut_(1,_29) + 410 cut_(2,_29) + trim_29
#  - 6000 useBar_29 = 0
#
# capacity_30: 1820 cut_(0,_30) + 2350 cut_(1,_30) + 410 cut_(2,_30) + trim_30
#  - 6000 useBar_30 = 0
#
# capacity_31: 1820 cut_(0,_31) + 2350 cut_(1,_31) + 410 cut_(2,_31) + trim_31
#  - 6000 useBar_31 = 0
#
# capacity_32: 1820 cut_(0,_32) + 2350 cut_(1,_32) + 410 cut_(2,_32) + trim_32
#  - 6000 useBar_32 = 0
#
# capacity_33: 1820 cut_(0,_33) + 2350 cut_(1,_33) + 410 cut_(2,_33) + trim_33
#  - 6000 useBar_33 = 0
#
# sym_0: - trim_0 + trim_1 + 6000 useBar_0 - 6000 useBar_1 >= 0
#
# sym_1: - trim_1 + trim_2 + 6000 useBar_1 - 6000 useBar_2 >= 0
#
# sym_2: - trim_2 + trim_3 + 6000 useBar_2 - 6000 useBar_3 >= 0
#
# sym_3: - trim_3 + trim_4 + 6000 useBar_3 - 6000 useBar_4 >= 0
#
# sym_4: - trim_4 + trim_5 + 6000 useBar_4 - 6000 useBar_5 >= 0
#
# sym_5: - trim_5 + trim_6 + 6000 useBar_5 - 6000 useBar_6 >= 0
#
# sym_6: - trim_6 + trim_7 + 6000 useBar_6 - 6000 useBar_7 >= 0
#
# sym_7: - trim_7 + trim_8 + 6000 useBar_7 - 6000 useBar_8 >= 0
#
# sym_8: - trim_8 + trim_9 + 6000 useBar_8 - 6000 useBar_9 >= 0
#
# sym_9: trim_10 - trim_9 - 6000 useBar_10 + 6000 useBar_9 >= 0
#
# sym_10: - trim_10 + trim_11 + 6000 useBar_10 - 6000 useBar_11 >= 0
#
# sym_11: - trim_11 + trim_12 + 6000 useBar_11 - 6000 useBar_12 >= 0
#
# sym_12: - trim_12 + trim_13 + 6000 useBar_12 - 6000 useBar_13 >= 0
#
# sym_13: - trim_13 + trim_14 + 6000 useBar_13 - 6000 useBar_14 >= 0
#
# sym_14: - trim_14 + trim_15 + 6000 useBar_14 - 6000 useBar_15 >= 0
#
# sym_15: - trim_15 + trim_16 + 6000 useBar_15 - 6000 useBar_16 >= 0
#
# sym_16: - trim_16 + trim_17 + 6000 useBar_16 - 6000 useBar_17 >= 0
#
# sym_17: - trim_17 + trim_18 + 6000 useBar_17 - 6000 useBar_18 >= 0
#
# sym_18: - trim_18 + trim_19 + 6000 useBar_18 - 6000 useBar_19 >= 0
#
# sym_19: - trim_19 + trim_20 + 6000 useBar_19 - 6000 useBar_20 >= 0
#
# sym_20: - trim_20 + trim_21 + 6000 useBar_20 - 6000 useBar_21 >= 0
#
# sym_21: - trim_21 + trim_22 + 6000 useBar_21 - 6000 useBar_22 >= 0
#
# sym_22: - trim_22 + trim_23 + 6000 useBar_22 - 6000 useBar_23 >= 0
#
# sym_23: - trim_23 + trim_24 + 6000 useBar_23 - 6000 useBar_24 >= 0
#
# sym_24: - trim_24 + trim_25 + 6000 useBar_24 - 6000 useBar_25 >= 0
#
# sym_25: - trim_25 + trim_26 + 6000 useBar_25 - 6000 useBar_26 >= 0
#
# sym_26: - trim_26 + trim_27 + 6000 useBar_26 - 6000 useBar_27 >= 0
#
# sym_27: - trim_27 + trim_28 + 6000 useBar_27 - 6000 useBar_28 >= 0
#
# sym_28: - trim_28 + trim_29 + 6000 useBar_28 - 6000 useBar_29 >= 0
#
# sym_29: - trim_29 + trim_30 + 6000 useBar_29 - 6000 useBar_30 >= 0
#
# sym_30: - trim_30 + trim_31 + 6000 useBar_30 - 6000 useBar_31 >= 0
#
# sym_31: - trim_31 + trim_32 + 6000 useBar_31 - 6000 useBar_32 >= 0
#
# sym_32: - trim_32 + trim_33 + 6000 useBar_32 - 6000 useBar_33 >= 0
#
# VARIABLES
# 0 <= cut_(0,_0) Integer
# 0 <= cut_(0,_1) Integer
# 0 <= cut_(0,_10) Integer
# 0 <= cut_(0,_11) Integer
# 0 <= cut_(0,_12) Integer
# 0 <= cut_(0,_13) Integer
# 0 <= cut_(0,_14) Integer
# 0 <= cut_(0,_15) Integer
# 0 <= cut_(0,_16) Integer
# 0 <= cut_(0,_17) Integer
# 0 <= cut_(0,_18) Integer
# 0 <= cut_(0,_19) Integer
# 0 <= cut_(0,_2) Integer
# 0 <= cut_(0,_20) Integer
# 0 <= cut_(0,_21) Integer
# 0 <= cut_(0,_22) Integer
# 0 <= cut_(0,_23) Integer
# 0 <= cut_(0,_24) Integer
# 0 <= cut_(0,_25) Integer
# 0 <= cut_(0,_26) Integer
# 0 <= cut_(0,_27) Integer
# 0 <= cut_(0,_28) Integer
# 0 <= cut_(0,_29) Integer
# 0 <= cut_(0,_3) Integer
# 0 <= cut_(0,_30) Integer
# 0 <= cut_(0,_31) Integer
# 0 <= cut_(0,_32) Integer
# 0 <= cut_(0,_33) Integer
# 0 <= cut_(0,_4) Integer
# 0 <= cut_(0,_5) Integer
# 0 <= cut_(0,_6) Integer
# 0 <= cut_(0,_7) Integer
# 0 <= cut_(0,_8) Integer
# 0 <= cut_(0,_9) Integer
# 0 <= cut_(1,_0) Integer
# 0 <= cut_(1,_1) Integer
# 0 <= cut_(1,_10) Integer
# 0 <= cut_(1,_11) Integer
# 0 <= cut_(1,_12) Integer
# 0 <= cut_(1,_13) Integer
# 0 <= cut_(1,_14) Integer
# 0 <= cut_(1,_15) Integer
# 0 <= cut_(1,_16) Integer
# 0 <= cut_(1,_17) Integer
# 0 <= cut_(1,_18) Integer
# 0 <= cut_(1,_19) Integer
# 0 <= cut_(1,_2) Integer
# 0 <= cut_(1,_20) Integer
# 0 <= cut_(1,_21) Integer
# 0 <= cut_(1,_22) Integer
# 0 <= cut_(1,_23) Integer
# 0 <= cut_(1,_24) Integer
# 0 <= cut_(1,_25) Integer
# 0 <= cut_(1,_26) Integer
# 0 <= cut_(1,_27) Integer
# 0 <= cut_(1,_28) Integer
# 0 <= cut_(1,_29) Integer
# 0 <= cut_(1,_3) Integer
# 0 <= cut_(1,_30) Integer
# 0 <= cut_(1,_31) Integer
# 0 <= cut_(1,_32) Integer
# 0 <= cut_(1,_33) Integer
# 0 <= cut_(1,_4) Integer
# 0 <= cut_(1,_5) Integer
# 0 <= cut_(1,_6) Integer
# 0 <= cut_(1,_7) Integer
# 0 <= cut_(1,_8) Integer
# 0 <= cut_(1,_9) Integer
# 0 <= cut_(2,_0) Integer
# 0 <= cut_(2,_1) Integer
# 0 <= cut_(2,_10) Integer
# 0 <= cut_(2,_11) Integer
# 0 <= cut_(2,_12) Integer
# 0 <= cut_(2,_13) Integer
# 0 <= cut_(2,_14) Integer
# 0 <= cut_(2,_15) Integer
# 0 <= cut_(2,_16) Integer
# 0 <= cut_(2,_17) Integer
# 0 <= cut_(2,_18) Integer
# 0 <= cut_(2,_19) Integer
# 0 <= cut_(2,_2) Integer
# 0 <= cut_(2,_20) Integer
# 0 <= cut_(2,_21) Integer
# 0 <= cut_(2,_22) Integer
# 0 <= cut_(2,_23) Integer
# 0 <= cut_(2,_24) Integer
# 0 <= cut_(2,_25) Integer
# 0 <= cut_(2,_26) Integer
# 0 <= cut_(2,_27) Integer
# 0 <= cut_(2,_28) Integer
# 0 <= cut_(2,_29) Integer
# 0 <= cut_(2,_3) Integer
# 0 <= cut_(2,_30) Integer
# 0 <= cut_(2,_31) Integer
# 0 <= cut_(2,_32) Integer
# 0 <= cut_(2,_33) Integer
# 0 <= cut_(2,_4) Integer
# 0 <= cut_(2,_5) Integer
# 0 <= cut_(2,_6) Integer
# 0 <= cut_(2,_7) Integer
# 0 <= cut_(2,_8) Integer
# 0 <= cut_(2,_9) Integer
# trim_0 Continuous
# trim_1 Continuous
# trim_10 Continuous
# trim_11 Continuous
# trim_12 Continuous
# trim_13 Continuous
# trim_14 Continuous
# trim_15 Continuous
# trim_16 Continuous
# trim_17 Continuous
# trim_18 Continuous
# trim_19 Continuous
# trim_2 Continuous
# trim_20 Continuous
# trim_21 Continuous
# trim_22 Continuous
# trim_23 Continuous
# trim_24 Continuous
# trim_25 Continuous
# trim_26 Continuous
# trim_27 Continuous
# trim_28 Continuous
# trim_29 Continuous
# trim_3 Continuous
# trim_30 Continuous
# trim_31 Continuous
# trim_32 Continuous
# trim_33 Continuous
# trim_4 Continuous
# trim_5 Continuous
# trim_6 Continuous
# trim_7 Continuous
# trim_8 Continuous
# trim_9 Continuous
# 0 <= useBar_0 <= 1 Integer
# 0 <= useBar_1 <= 1 Integer
# 0 <= useBar_10 <= 1 Integer
# 0 <= useBar_11 <= 1 Integer
# 0 <= useBar_12 <= 1 Integer
# 0 <= useBar_13 <= 1 Integer
# 0 <= useBar_14 <= 1 Integer
# 0 <= useBar_15 <= 1 Integer
# 0 <= useBar_16 <= 1 Integer
# 0 <= useBar_17 <= 1 Integer
# 0 <= useBar_18 <= 1 Integer
# 0 <= useBar_19 <= 1 Integer
# 0 <= useBar_2 <= 1 Integer
# 0 <= useBar_20 <= 1 Integer
# 0 <= useBar_21 <= 1 Integer
# 0 <= useBar_22 <= 1 Integer
# 0 <= useBar_23 <= 1 Integer
# 0 <= useBar_24 <= 1 Integer
# 0 <= useBar_25 <= 1 Integer
# 0 <= useBar_26 <= 1 Integer
# 0 <= useBar_27 <= 1 Integer
# 0 <= useBar_28 <= 1 Integer
# 0 <= useBar_29 <= 1 Integer
# 0 <= useBar_3 <= 1 Integer
# 0 <= useBar_30 <= 1 Integer
# 0 <= useBar_31 <= 1 Integer
# 0 <= useBar_32 <= 1 Integer
# 0 <= useBar_33 <= 1 Integer
# 0 <= useBar_4 <= 1 Integer
# 0 <= useBar_5 <= 1 Integer
# 0 <= useBar_6 <= 1 Integer
# 0 <= useBar_7 <= 1 Integer
# 0 <= useBar_8 <= 1 Integer
# 0 <= useBar_9 <= 1 Integer
